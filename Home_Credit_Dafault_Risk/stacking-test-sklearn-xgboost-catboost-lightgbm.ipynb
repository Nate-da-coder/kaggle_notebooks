# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
NFOLDS = 3
SEED = 0
NROWS = None

# %%
data = pd.read_csv('../input/home-credit-default-risk/application_train.csv')
test = pd.read_csv('../input/home-credit-default-risk/application_test.csv')
prev = pd.read_csv('../input/home-credit-default-risk/previous_application.csv')

# %%
categorical_feats = [
    f for f in data.columns if data[f].dtype == 'object'
]
for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])
    test[f_] = indexer.get_indexer(test[f_])

# %%
gc.enable()

# %%
y_train = data['TARGET']
del data['TARGET']

# %%
prev_cat_features = [
    f_ for f_ in prev.columns if prev[f_].dtype =='object'
]
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])

# %%
avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

# %%
x_train = data.merge(right = avg_prev.reset_index(), how='left', on = 'SK_ID_CURR')
x_test = test.merge(right = avg_prev.reset_index(), how='left', on='SK_ID_CURR')

# %%
x_train = x_train.fillna(0)
x_test = x_test.fillna(0)

# %%
ntrain = x_train.shape[0]
ntest = x_test.shape[0]

# %%
excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

# %%
x_train = x_train[features]
x_test = x_test[features]

# %%
x_train.head()
# Out:
#    NAME_CONTRACT_TYPE_x  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0                     0            0             0                0
# 1                     0            1             0                1
# 2                     1            0             1                0
# 3                     0            1             0                0
# 4                     0            0             0                0
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY_x  \
# 0             0          202500.0      406597.5        24700.5
# 1             0          270000.0     1293502.5        35698.5
# 2             0           67500.0      135000.0         6750.0
# 3             0          135000.0      312682.5        29686.5
# 4             0          121500.0      513000.0        21865.5
#
#    AMT_GOODS_PRICE_x  NAME_TYPE_SUITE_x  ...  CNT_PAYMENT  NAME_YIELD_GROUP  \
# 0           351000.0                  0  ...    24.000000          3.000000
# 1          1129500.0                  1  ...    10.000000          1.000000
# 2           135000.0                  0  ...     4.000000          0.000000
# 3           297000.0                  0  ...    23.000000          2.888889
# 4           513000.0                  0  ...    20.666667          1.000000
#
#    PRODUCT_COMBINATION  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  \
# 0             8.000000            365243.0     -565.000000
# 1             6.666667            365243.0    -1274.333333
# 2            10.000000            365243.0     -784.000000
# 3             5.888889            365243.0    91066.500000
# 4             3.333333            365243.0    -1263.200000
#
#    DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 0                 125.000000     -25.000000        -17.000000
# 1               -1004.333333   -1054.333333      -1047.333333
# 2                -694.000000    -724.000000       -714.000000
# 3               91584.000000  182477.500000     182481.750000
# 4                -837.200000   72136.200000      72143.800000
#
#    NFLAG_INSURED_ON_APPROVAL  nb_app
# 0                   0.000000     1.0
# 1                   0.666667     3.0
# 2                   0.000000     1.0
# 3                   0.000000     9.0
# 4                   0.600000     6.0
#
# [5 rows x 156 columns]

# %%
kf = KFold(n_splits = NFOLDS, shuffle = True, random_state = SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed = 0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)
    
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
    
    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]
    
class CatboostWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
        params['random_seed'] = seed
        self.clf = clf(**params)
        
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
    
    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]
    
    
class LightGBMWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)
        
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
    
    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]
    
class XgbWrapper(object):
    def __init__(self, seed = 0, params = None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)
        
    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label = y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)
    
    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

# %%
# out of fold
def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest)) # 3 X ntest
    
    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]
        
        clf.train(x_tr, y_tr)
        
        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i,:] = clf.predict(x_test)
        
    oof_test[:] = oof_test_skf.mean(axis = 0)
    return oof_train.reshape(-1,1), oof_test.reshape(-1,1)

# %%
et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators':200,
    'learning_rate':0.1,
    'num_leaves':123,
    'colsample_bytree':0.8,
    'subsample':0.9,
    'max_depth':15,
    'reg_alpha':0.1,
    'reg_lambda':0.1,
    'min_split_gain':0.01,
    'min_child_weight':2    
}

# %%
xg = XgbWrapper(seed = SEED, params = xgb_params)
et = SklearnWrapper(clf = ExtraTreesClassifier, seed = SEED, params = et_params)
rf = SklearnWrapper(clf = RandomForestClassifier, seed = SEED, params = rf_params)
cb = CatboostWrapper(clf = CatBoostClassifier, seed = SEED, params = catboost_params)
lg = LightGBMWrapper(clf = LGBMClassifier, seed = SEED, params = lightgbm_params)

xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)
# Out:
# [09:19:23] WARNING: ../src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [09:20:37] WARNING: ../src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [09:21:50] WARNING: ../src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# 0:	total: 127ms	remaining: 25.3s
# 1:	total: 201ms	remaining: 19.9s
# 2:	total: 246ms	remaining: 16.2s
# 3:	total: 302ms	remaining: 14.8s
# 4:	total: 369ms	remaining: 14.4s
# 5:	total: 428ms	remaining: 13.8s
# 6:	total: 479ms	remaining: 13.2s
# 7:	total: 524ms	remaining: 12.6s
# 8:	total: 579ms	remaining: 12.3s
# 9:	total: 635ms	remaining: 12.1s
# 10:	total: 682ms	remaining: 11.7s
# 11:	total: 733ms	remaining: 11.5s
# 12:	total: 793ms	remaining: 11.4s
# 13:	total: 847ms	remaining: 11.3s
# 14:	total: 901ms	remaining: 11.1s
# 15:	total: 949ms	remaining: 10.9s
# 16:	total: 989ms	remaining: 10.6s
# 17:	total: 1.04s	remaining: 10.5s
# 18:	total: 1.08s	remaining: 10.3s
# 19:	total: 1.13s	remaining: 10.1s
# 20:	total: 1.17s	remaining: 9.98s
# 21:	total: 1.22s	remaining: 9.86s
# 22:	total: 1.28s	remaining: 9.85s
# 23:	total: 1.34s	remaining: 9.84s
# 24:	total: 1.39s	remaining: 9.74s
# 25:	total: 1.45s	remaining: 9.68s
# 26:	total: 1.5s	remaining: 9.63s
# 27:	total: 1.55s	remaining: 9.54s
# 28:	total: 1.6s	remaining: 9.41s
# 29:	total: 1.64s	remaining: 9.32s
# 30:	total: 1.7s	remaining: 9.24s
# 31:	total: 1.75s	remaining: 9.16s
# 32:	total: 1.79s	remaining: 9.07s
# 33:	total: 1.83s	remaining: 8.95s
# 34:	total: 1.87s	remaining: 8.84s
# 35:	total: 1.92s	remaining: 8.77s
# 36:	total: 1.97s	remaining: 8.67s
# 37:	total: 2.02s	remaining: 8.6s
# 38:	total: 2.07s	remaining: 8.55s
# 39:	total: 2.12s	remaining: 8.48s
# 40:	total: 2.17s	remaining: 8.43s
# 41:	total: 2.25s	remaining: 8.46s
# 42:	total: 2.32s	remaining: 8.48s
# 43:	total: 2.37s	remaining: 8.41s
# 44:	total: 2.42s	remaining: 8.34s
# 45:	total: 2.48s	remaining: 8.3s
# 46:	total: 2.53s	remaining: 8.23s
# 47:	total: 2.58s	remaining: 8.15s
# 48:	total: 2.62s	remaining: 8.08s
# 49:	total: 2.67s	remaining: 8.01s
# 50:	total: 2.72s	remaining: 7.96s
# 51:	total: 2.77s	remaining: 7.89s
# 52:	total: 2.83s	remaining: 7.84s
# 53:	total: 2.88s	remaining: 7.79s
# 54:	total: 2.94s	remaining: 7.74s
# 55:	total: 2.98s	remaining: 7.66s
# 56:	total: 3.03s	remaining: 7.61s
# 57:	total: 3.08s	remaining: 7.54s
# 58:	total: 3.12s	remaining: 7.47s
# 59:	total: 3.17s	remaining: 7.41s
# 60:	total: 3.22s	remaining: 7.35s
# 61:	total: 3.27s	remaining: 7.28s
# 62:	total: 3.32s	remaining: 7.22s
# 63:	total: 3.36s	remaining: 7.15s
# 64:	total: 3.4s	remaining: 7.07s
# 65:	total: 3.44s	remaining: 6.99s
# 66:	total: 3.5s	remaining: 6.95s
# 67:	total: 3.56s	remaining: 6.9s
# 68:	total: 3.61s	remaining: 6.85s
# 69:	total: 3.65s	remaining: 6.78s
# 70:	total: 3.7s	remaining: 6.73s
# 71:	total: 3.75s	remaining: 6.67s
# 72:	total: 3.8s	remaining: 6.61s
# 73:	total: 3.85s	remaining: 6.55s
# 74:	total: 3.89s	remaining: 6.48s
# 75:	total: 3.96s	remaining: 6.45s
# 76:	total: 4s	remaining: 6.38s
# 77:	total: 4.04s	remaining: 6.32s
# 78:	total: 4.08s	remaining: 6.25s
# 79:	total: 4.13s	remaining: 6.2s
# 80:	total: 4.19s	remaining: 6.15s
# 81:	total: 4.24s	remaining: 6.1s
# 82:	total: 4.29s	remaining: 6.04s
# 83:	total: 4.34s	remaining: 5.99s
# 84:	total: 4.4s	remaining: 5.95s
# 85:	total: 4.45s	remaining: 5.89s
# 86:	total: 4.5s	remaining: 5.84s
# 87:	total: 4.54s	remaining: 5.78s
# 88:	total: 4.59s	remaining: 5.73s
# 89:	total: 4.64s	remaining: 5.67s
# 90:	total: 4.68s	remaining: 5.6s
# 91:	total: 4.73s	remaining: 5.56s
# 92:	total: 4.78s	remaining: 5.5s
# 93:	total: 4.83s	remaining: 5.45s
# 94:	total: 4.87s	remaining: 5.39s
# 95:	total: 4.92s	remaining: 5.33s
# 96:	total: 4.97s	remaining: 5.27s
# 97:	total: 5.03s	remaining: 5.24s
# 98:	total: 5.07s	remaining: 5.17s
# 99:	total: 5.12s	remaining: 5.12s
# 100:	total: 5.17s	remaining: 5.06s
# 101:	total: 5.22s	remaining: 5.02s
# 102:	total: 5.27s	remaining: 4.96s
# 103:	total: 5.31s	remaining: 4.91s
# 104:	total: 5.37s	remaining: 4.86s
# 105:	total: 5.42s	remaining: 4.81s
# 106:	total: 5.46s	remaining: 4.75s
# 107:	total: 5.51s	remaining: 4.7s
# 108:	total: 5.56s	remaining: 4.64s
# 109:	total: 5.61s	remaining: 4.59s
# 110:	total: 5.66s	remaining: 4.53s
# 111:	total: 5.71s	remaining: 4.48s
# 112:	total: 5.75s	remaining: 4.43s
# 113:	total: 5.8s	remaining: 4.38s
# 114:	total: 5.86s	remaining: 4.33s
# 115:	total: 5.91s	remaining: 4.28s
# 116:	total: 5.95s	remaining: 4.22s
# 117:	total: 6s	remaining: 4.17s
# 118:	total: 6.04s	remaining: 4.11s
# 119:	total: 6.09s	remaining: 4.06s
# 120:	total: 6.14s	remaining: 4.01s
# 121:	total: 6.18s	remaining: 3.95s
# 122:	total: 6.24s	remaining: 3.9s
# 123:	total: 6.3s	remaining: 3.86s
# 124:	total: 6.36s	remaining: 3.81s
# 125:	total: 6.41s	remaining: 3.76s
# 126:	total: 6.45s	remaining: 3.71s
# 127:	total: 6.5s	remaining: 3.65s
# 128:	total: 6.54s	remaining: 3.6s
# 129:	total: 6.59s	remaining: 3.55s
# 130:	total: 6.64s	remaining: 3.5s
# 131:	total: 6.69s	remaining: 3.44s
# 132:	total: 6.74s	remaining: 3.39s
# 133:	total: 6.79s	remaining: 3.34s
# 134:	total: 6.84s	remaining: 3.29s
# 135:	total: 6.88s	remaining: 3.24s
# 136:	total: 6.93s	remaining: 3.19s
# 137:	total: 6.99s	remaining: 3.14s
# 138:	total: 7.04s	remaining: 3.09s
# 139:	total: 7.09s	remaining: 3.04s
# 140:	total: 7.15s	remaining: 2.99s
# 141:	total: 7.21s	remaining: 2.94s
# 142:	total: 7.25s	remaining: 2.89s
# 143:	total: 7.3s	remaining: 2.84s
# 144:	total: 7.35s	remaining: 2.79s
# 145:	total: 7.4s	remaining: 2.73s
# 146:	total: 7.45s	remaining: 2.69s
# 147:	total: 7.5s	remaining: 2.63s
# 148:	total: 7.55s	remaining: 2.58s
# 149:	total: 7.6s	remaining: 2.53s
# 150:	total: 7.67s	remaining: 2.49s
# 151:	total: 7.71s	remaining: 2.43s
# 152:	total: 7.76s	remaining: 2.38s
# 153:	total: 7.8s	remaining: 2.33s
# 154:	total: 7.85s	remaining: 2.28s
# 155:	total: 7.9s	remaining: 2.23s
# 156:	total: 7.97s	remaining: 2.18s
# 157:	total: 8.02s	remaining: 2.13s
# 158:	total: 8.07s	remaining: 2.08s
# 159:	total: 8.12s	remaining: 2.03s
# 160:	total: 8.16s	remaining: 1.98s
# 161:	total: 8.21s	remaining: 1.92s
# 162:	total: 8.25s	remaining: 1.87s
# 163:	total: 8.3s	remaining: 1.82s
# 164:	total: 8.36s	remaining: 1.77s
# 165:	total: 8.4s	remaining: 1.72s
# 166:	total: 8.45s	remaining: 1.67s
# 167:	total: 8.49s	remaining: 1.62s
# 168:	total: 8.54s	remaining: 1.57s
# 169:	total: 8.59s	remaining: 1.51s
# 170:	total: 8.65s	remaining: 1.47s
# 171:	total: 8.7s	remaining: 1.42s
# 172:	total: 8.75s	remaining: 1.36s
# 173:	total: 8.8s	remaining: 1.31s
# 174:	total: 8.85s	remaining: 1.26s
# 175:	total: 8.89s	remaining: 1.21s
# 176:	total: 8.95s	remaining: 1.16s
# 177:	total: 9s	remaining: 1.11s
# 178:	total: 9.05s	remaining: 1.06s
# 179:	total: 9.12s	remaining: 1.01s
# 180:	total: 9.18s	remaining: 963ms
# 181:	total: 9.23s	remaining: 913ms
# 182:	total: 9.3s	remaining: 864ms
# 183:	total: 9.35s	remaining: 813ms
# 184:	total: 9.4s	remaining: 762ms
# 185:	total: 9.45s	remaining: 711ms
# 186:	total: 9.49s	remaining: 660ms
# 187:	total: 9.54s	remaining: 609ms
# 188:	total: 9.6s	remaining: 559ms
# 189:	total: 9.65s	remaining: 508ms
# 190:	total: 9.7s	remaining: 457ms
# 191:	total: 9.76s	remaining: 407ms
# 192:	total: 9.82s	remaining: 356ms
# 193:	total: 9.86s	remaining: 305ms
# 194:	total: 9.9s	remaining: 254ms
# 195:	total: 9.95s	remaining: 203ms
# 196:	total: 9.99s	remaining: 152ms
# 197:	total: 10s	remaining: 102ms
# 198:	total: 10.1s	remaining: 50.7ms
# 199:	total: 10.1s	remaining: 0us
# 0:	total: 70.4ms	remaining: 14s
# 1:	total: 121ms	remaining: 12s
# 2:	total: 174ms	remaining: 11.4s
# 3:	total: 231ms	remaining: 11.3s
# 4:	total: 286ms	remaining: 11.1s
# 5:	total: 341ms	remaining: 11s
# 6:	total: 396ms	remaining: 10.9s
# 7:	total: 445ms	remaining: 10.7s
# 8:	total: 498ms	remaining: 10.6s
# 9:	total: 548ms	remaining: 10.4s
# 10:	total: 610ms	remaining: 10.5s
# 11:	total: 664ms	remaining: 10.4s
# 12:	total: 710ms	remaining: 10.2s
# 13:	total: 773ms	remaining: 10.3s
# 14:	total: 823ms	remaining: 10.2s
# 15:	total: 881ms	remaining: 10.1s
# 16:	total: 921ms	remaining: 9.92s
# 17:	total: 963ms	remaining: 9.73s
# 18:	total: 1.02s	remaining: 9.71s
# 19:	total: 1.07s	remaining: 9.64s
# 20:	total: 1.12s	remaining: 9.54s
# 21:	total: 1.17s	remaining: 9.46s
# 22:	total: 1.21s	remaining: 9.34s
# 23:	total: 1.26s	remaining: 9.28s
# 24:	total: 1.32s	remaining: 9.26s
# 25:	total: 1.38s	remaining: 9.21s
# 26:	total: 1.43s	remaining: 9.16s
# 27:	total: 1.49s	remaining: 9.12s
# 28:	total: 1.53s	remaining: 9.01s
# 29:	total: 1.57s	remaining: 8.93s
# 30:	total: 1.63s	remaining: 8.87s
# 31:	total: 1.67s	remaining: 8.79s
# 32:	total: 1.74s	remaining: 8.82s
# 33:	total: 1.79s	remaining: 8.74s
# 34:	total: 1.84s	remaining: 8.68s
# 35:	total: 1.89s	remaining: 8.59s
# 36:	total: 1.94s	remaining: 8.53s
# 37:	total: 1.99s	remaining: 8.48s
# 38:	total: 2.05s	remaining: 8.47s
# 39:	total: 2.12s	remaining: 8.47s
# 40:	total: 2.17s	remaining: 8.42s
# 41:	total: 2.23s	remaining: 8.37s
# 42:	total: 2.27s	remaining: 8.29s
# 43:	total: 2.31s	remaining: 8.21s
# 44:	total: 2.37s	remaining: 8.16s
# 45:	total: 2.42s	remaining: 8.1s
# 46:	total: 2.46s	remaining: 8.02s
# 47:	total: 2.52s	remaining: 8s
# 48:	total: 2.57s	remaining: 7.92s
# 49:	total: 2.62s	remaining: 7.85s
# 50:	total: 2.66s	remaining: 7.77s
# 51:	total: 2.71s	remaining: 7.71s
# 52:	total: 2.75s	remaining: 7.64s
# 53:	total: 2.81s	remaining: 7.6s
# 54:	total: 2.86s	remaining: 7.54s
# 55:	total: 2.91s	remaining: 7.48s
# 56:	total: 2.96s	remaining: 7.42s
# 57:	total: 3.01s	remaining: 7.36s
# 58:	total: 3.06s	remaining: 7.31s
# 59:	total: 3.11s	remaining: 7.26s
# 60:	total: 3.16s	remaining: 7.2s
# 61:	total: 3.2s	remaining: 7.12s
# 62:	total: 3.25s	remaining: 7.07s
# 63:	total: 3.29s	remaining: 7s
# 64:	total: 3.34s	remaining: 6.94s
# 65:	total: 3.38s	remaining: 6.87s
# 66:	total: 3.45s	remaining: 6.85s
# 67:	total: 3.5s	remaining: 6.79s
# 68:	total: 3.55s	remaining: 6.73s
# 69:	total: 3.59s	remaining: 6.67s
# 70:	total: 3.63s	remaining: 6.6s
# 71:	total: 3.7s	remaining: 6.57s
# 72:	total: 3.74s	remaining: 6.51s
# 73:	total: 3.79s	remaining: 6.46s
# 74:	total: 3.84s	remaining: 6.39s
# 75:	total: 3.88s	remaining: 6.33s
# 76:	total: 3.94s	remaining: 6.29s
# 77:	total: 3.99s	remaining: 6.25s
# 78:	total: 4.04s	remaining: 6.2s
# 79:	total: 4.11s	remaining: 6.17s
# 80:	total: 4.17s	remaining: 6.12s
# 81:	total: 4.21s	remaining: 6.07s
# 82:	total: 4.28s	remaining: 6.03s
# 83:	total: 4.33s	remaining: 5.99s
# 84:	total: 4.39s	remaining: 5.94s
# 85:	total: 4.43s	remaining: 5.87s
# 86:	total: 4.47s	remaining: 5.81s
# 87:	total: 4.52s	remaining: 5.75s
# 88:	total: 4.58s	remaining: 5.71s
# 89:	total: 4.63s	remaining: 5.66s
# 90:	total: 4.68s	remaining: 5.61s
# 91:	total: 4.75s	remaining: 5.57s
# 92:	total: 4.8s	remaining: 5.52s
# 93:	total: 4.85s	remaining: 5.47s
# 94:	total: 4.9s	remaining: 5.41s
# 95:	total: 4.96s	remaining: 5.38s
# 96:	total: 5.01s	remaining: 5.32s
# 97:	total: 5.06s	remaining: 5.27s
# 98:	total: 5.11s	remaining: 5.22s
# 99:	total: 5.16s	remaining: 5.16s
# 100:	total: 5.22s	remaining: 5.12s
# 101:	total: 5.27s	remaining: 5.07s
# 102:	total: 5.32s	remaining: 5.01s
# 103:	total: 5.36s	remaining: 4.95s
# 104:	total: 5.41s	remaining: 4.89s
# 105:	total: 5.47s	remaining: 4.85s
# 106:	total: 5.52s	remaining: 4.8s
# 107:	total: 5.56s	remaining: 4.74s
# 108:	total: 5.62s	remaining: 4.69s
# 109:	total: 5.66s	remaining: 4.63s
# 110:	total: 5.71s	remaining: 4.58s
# 111:	total: 5.76s	remaining: 4.53s
# 112:	total: 5.81s	remaining: 4.47s
# 113:	total: 5.86s	remaining: 4.42s
# 114:	total: 5.91s	remaining: 4.37s
# 115:	total: 5.96s	remaining: 4.32s
# 116:	total: 6.01s	remaining: 4.26s
# 117:	total: 6.05s	remaining: 4.2s
# 118:	total: 6.09s	remaining: 4.15s
# 119:	total: 6.14s	remaining: 4.1s
# 120:	total: 6.19s	remaining: 4.04s
# 121:	total: 6.24s	remaining: 3.99s
# 122:	total: 6.3s	remaining: 3.95s
# 123:	total: 6.34s	remaining: 3.89s
# 124:	total: 6.39s	remaining: 3.84s
# 125:	total: 6.44s	remaining: 3.78s
# 126:	total: 6.5s	remaining: 3.73s
# 127:	total: 6.54s	remaining: 3.68s
# 128:	total: 6.6s	remaining: 3.63s
# 129:	total: 6.64s	remaining: 3.58s
# 130:	total: 6.69s	remaining: 3.52s
# 131:	total: 6.75s	remaining: 3.48s
# 132:	total: 6.8s	remaining: 3.43s
# 133:	total: 6.86s	remaining: 3.38s
# 134:	total: 6.92s	remaining: 3.33s
# 135:	total: 6.97s	remaining: 3.28s
# 136:	total: 7.03s	remaining: 3.23s
# 137:	total: 7.08s	remaining: 3.18s
# 138:	total: 7.13s	remaining: 3.13s
# 139:	total: 7.18s	remaining: 3.08s
# 140:	total: 7.24s	remaining: 3.03s
# 141:	total: 7.29s	remaining: 2.98s
# 142:	total: 7.34s	remaining: 2.93s
# 143:	total: 7.39s	remaining: 2.88s
# 144:	total: 7.44s	remaining: 2.82s
# 145:	total: 7.48s	remaining: 2.77s
# 146:	total: 7.53s	remaining: 2.72s
# 147:	total: 7.58s	remaining: 2.66s
# 148:	total: 7.64s	remaining: 2.61s
# 149:	total: 7.68s	remaining: 2.56s
# 150:	total: 7.73s	remaining: 2.51s
# 151:	total: 7.78s	remaining: 2.46s
# 152:	total: 7.83s	remaining: 2.4s
# 153:	total: 7.87s	remaining: 2.35s
# 154:	total: 7.92s	remaining: 2.3s
# 155:	total: 7.97s	remaining: 2.25s
# 156:	total: 8.04s	remaining: 2.2s
# 157:	total: 8.08s	remaining: 2.15s
# 158:	total: 8.14s	remaining: 2.1s
# 159:	total: 8.19s	remaining: 2.05s
# 160:	total: 8.24s	remaining: 2s
# 161:	total: 8.29s	remaining: 1.95s
# 162:	total: 8.34s	remaining: 1.89s
# 163:	total: 8.4s	remaining: 1.84s
# 164:	total: 8.45s	remaining: 1.79s
# 165:	total: 8.49s	remaining: 1.74s
# 166:	total: 8.54s	remaining: 1.69s
# 167:	total: 8.59s	remaining: 1.64s
# 168:	total: 8.63s	remaining: 1.58s
# 169:	total: 8.68s	remaining: 1.53s
# 170:	total: 8.73s	remaining: 1.48s
# 171:	total: 8.78s	remaining: 1.43s
# 172:	total: 8.83s	remaining: 1.38s
# 173:	total: 8.89s	remaining: 1.33s
# 174:	total: 8.94s	remaining: 1.28s
# 175:	total: 9s	remaining: 1.23s
# 176:	total: 9.04s	remaining: 1.17s
# 177:	total: 9.09s	remaining: 1.12s
# 178:	total: 9.14s	remaining: 1.07s
# 179:	total: 9.2s	remaining: 1.02s
# 180:	total: 9.26s	remaining: 972ms
# 181:	total: 9.31s	remaining: 921ms
# 182:	total: 9.36s	remaining: 870ms
# 183:	total: 9.4s	remaining: 818ms
# 184:	total: 9.46s	remaining: 767ms
# 185:	total: 9.5s	remaining: 715ms
# 186:	total: 9.55s	remaining: 664ms
# 187:	total: 9.6s	remaining: 613ms
# 188:	total: 9.64s	remaining: 561ms
# 189:	total: 9.7s	remaining: 511ms
# 190:	total: 9.75s	remaining: 459ms
# 191:	total: 9.81s	remaining: 409ms
# 192:	total: 9.85s	remaining: 357ms
# 193:	total: 9.89s	remaining: 306ms
# 194:	total: 9.95s	remaining: 255ms
# 195:	total: 10s	remaining: 204ms
# 196:	total: 10.1s	remaining: 153ms
# 197:	total: 10.1s	remaining: 102ms
# 198:	total: 10.1s	remaining: 51ms
# 199:	total: 10.2s	remaining: 0us
# 0:	total: 68.8ms	remaining: 13.7s
# 1:	total: 121ms	remaining: 11.9s
# 2:	total: 173ms	remaining: 11.3s
# 3:	total: 233ms	remaining: 11.4s
# 4:	total: 291ms	remaining: 11.4s
# 5:	total: 346ms	remaining: 11.2s
# 6:	total: 394ms	remaining: 10.9s
# 7:	total: 452ms	remaining: 10.8s
# 8:	total: 521ms	remaining: 11s
# 9:	total: 575ms	remaining: 10.9s
# 10:	total: 631ms	remaining: 10.8s
# 11:	total: 683ms	remaining: 10.7s
# 12:	total: 739ms	remaining: 10.6s
# 13:	total: 791ms	remaining: 10.5s
# 14:	total: 842ms	remaining: 10.4s
# 15:	total: 896ms	remaining: 10.3s
# 16:	total: 953ms	remaining: 10.3s
# 17:	total: 1.02s	remaining: 10.3s
# 18:	total: 1.07s	remaining: 10.2s
# 19:	total: 1.12s	remaining: 10.1s
# 20:	total: 1.18s	remaining: 10.1s
# 21:	total: 1.23s	remaining: 9.93s
# 22:	total: 1.28s	remaining: 9.83s
# 23:	total: 1.32s	remaining: 9.72s
# 24:	total: 1.38s	remaining: 9.68s
# 25:	total: 1.43s	remaining: 9.58s
# 26:	total: 1.48s	remaining: 9.51s
# 27:	total: 1.53s	remaining: 9.38s
# 28:	total: 1.59s	remaining: 9.38s
# 29:	total: 1.64s	remaining: 9.31s
# 30:	total: 1.69s	remaining: 9.22s
# 31:	total: 1.74s	remaining: 9.15s
# 32:	total: 1.8s	remaining: 9.13s
# 33:	total: 1.84s	remaining: 9.01s
# 34:	total: 1.9s	remaining: 8.94s
# 35:	total: 1.95s	remaining: 8.9s
# 36:	total: 2.02s	remaining: 8.88s
# 37:	total: 2.06s	remaining: 8.8s
# 38:	total: 2.12s	remaining: 8.73s
# 39:	total: 2.18s	remaining: 8.71s
# 40:	total: 2.22s	remaining: 8.62s
# 41:	total: 2.28s	remaining: 8.59s
# 42:	total: 2.33s	remaining: 8.5s
# 43:	total: 2.37s	remaining: 8.4s
# 44:	total: 2.41s	remaining: 8.31s
# 45:	total: 2.46s	remaining: 8.25s
# 46:	total: 2.52s	remaining: 8.19s
# 47:	total: 2.57s	remaining: 8.13s
# 48:	total: 2.61s	remaining: 8.06s
# 49:	total: 2.67s	remaining: 8.01s
# 50:	total: 2.73s	remaining: 7.99s
# 51:	total: 2.77s	remaining: 7.9s
# 52:	total: 2.82s	remaining: 7.82s
# 53:	total: 2.86s	remaining: 7.74s
# 54:	total: 2.91s	remaining: 7.68s
# 55:	total: 2.97s	remaining: 7.63s
# 56:	total: 3.01s	remaining: 7.55s
# 57:	total: 3.05s	remaining: 7.48s
# 58:	total: 3.11s	remaining: 7.44s
# 59:	total: 3.16s	remaining: 7.37s
# 60:	total: 3.21s	remaining: 7.31s
# 61:	total: 3.25s	remaining: 7.25s
# 62:	total: 3.3s	remaining: 7.18s
# 63:	total: 3.37s	remaining: 7.15s
# 64:	total: 3.42s	remaining: 7.1s
# 65:	total: 3.47s	remaining: 7.05s
# 66:	total: 3.52s	remaining: 6.99s
# 67:	total: 3.58s	remaining: 6.95s
# 68:	total: 3.62s	remaining: 6.88s
# 69:	total: 3.67s	remaining: 6.81s
# 70:	total: 3.73s	remaining: 6.78s
# 71:	total: 3.78s	remaining: 6.71s
# 72:	total: 3.82s	remaining: 6.65s
# 73:	total: 3.89s	remaining: 6.62s
# 74:	total: 3.93s	remaining: 6.55s
# 75:	total: 3.98s	remaining: 6.49s
# 76:	total: 4.03s	remaining: 6.44s
# 77:	total: 4.08s	remaining: 6.39s
# 78:	total: 4.13s	remaining: 6.32s
# 79:	total: 4.18s	remaining: 6.27s
# 80:	total: 4.23s	remaining: 6.22s
# 81:	total: 4.29s	remaining: 6.17s
# 82:	total: 4.33s	remaining: 6.11s
# 83:	total: 4.39s	remaining: 6.06s
# 84:	total: 4.43s	remaining: 6s
# 85:	total: 4.48s	remaining: 5.94s
# 86:	total: 4.53s	remaining: 5.88s
# 87:	total: 4.58s	remaining: 5.83s
# 88:	total: 4.63s	remaining: 5.77s
# 89:	total: 4.67s	remaining: 5.71s
# 90:	total: 4.74s	remaining: 5.68s
# 91:	total: 4.79s	remaining: 5.62s
# 92:	total: 4.83s	remaining: 5.56s
# 93:	total: 4.89s	remaining: 5.52s
# 94:	total: 4.93s	remaining: 5.45s
# 95:	total: 4.98s	remaining: 5.4s
# 96:	total: 5.04s	remaining: 5.35s
# 97:	total: 5.08s	remaining: 5.29s
# 98:	total: 5.13s	remaining: 5.24s
# 99:	total: 5.18s	remaining: 5.18s
# 100:	total: 5.24s	remaining: 5.14s
# 101:	total: 5.28s	remaining: 5.08s
# 102:	total: 5.35s	remaining: 5.04s
# 103:	total: 5.4s	remaining: 4.98s
# 104:	total: 5.45s	remaining: 4.93s
# 105:	total: 5.5s	remaining: 4.88s
# 106:	total: 5.55s	remaining: 4.82s
# 107:	total: 5.6s	remaining: 4.77s
# 108:	total: 5.66s	remaining: 4.72s
# 109:	total: 5.7s	remaining: 4.67s
# 110:	total: 5.75s	remaining: 4.61s
# 111:	total: 5.79s	remaining: 4.55s
# 112:	total: 5.83s	remaining: 4.49s
# 113:	total: 5.88s	remaining: 4.43s
# 114:	total: 5.92s	remaining: 4.37s
# 115:	total: 5.96s	remaining: 4.32s
# 116:	total: 6.01s	remaining: 4.26s
# 117:	total: 6.05s	remaining: 4.21s
# 118:	total: 6.1s	remaining: 4.15s
# 119:	total: 6.16s	remaining: 4.11s
# 120:	total: 6.21s	remaining: 4.05s
# 121:	total: 6.25s	remaining: 4s
# 122:	total: 6.3s	remaining: 3.94s
# 123:	total: 6.35s	remaining: 3.89s
# 124:	total: 6.39s	remaining: 3.83s
# 125:	total: 6.45s	remaining: 3.79s
# 126:	total: 6.5s	remaining: 3.73s
# 127:	total: 6.55s	remaining: 3.68s
# 128:	total: 6.59s	remaining: 3.63s
# 129:	total: 6.65s	remaining: 3.58s
# 130:	total: 6.7s	remaining: 3.53s
# 131:	total: 6.75s	remaining: 3.48s
# 132:	total: 6.81s	remaining: 3.43s
# 133:	total: 6.86s	remaining: 3.38s
# 134:	total: 6.91s	remaining: 3.33s
# 135:	total: 6.96s	remaining: 3.27s
# 136:	total: 7.01s	remaining: 3.22s
# 137:	total: 7.06s	remaining: 3.17s
# 138:	total: 7.11s	remaining: 3.12s
# 139:	total: 7.16s	remaining: 3.07s
# 140:	total: 7.22s	remaining: 3.02s
# 141:	total: 7.32s	remaining: 2.99s
# 142:	total: 7.36s	remaining: 2.93s
# 143:	total: 7.41s	remaining: 2.88s
# 144:	total: 7.45s	remaining: 2.83s
# 145:	total: 7.51s	remaining: 2.78s
# 146:	total: 7.56s	remaining: 2.72s
# 147:	total: 7.6s	remaining: 2.67s
# 148:	total: 7.66s	remaining: 2.62s
# 149:	total: 7.7s	remaining: 2.57s
# 150:	total: 7.76s	remaining: 2.52s
# 151:	total: 7.81s	remaining: 2.47s
# 152:	total: 7.86s	remaining: 2.41s
# 153:	total: 7.91s	remaining: 2.36s
# 154:	total: 7.96s	remaining: 2.31s
# 155:	total: 8.02s	remaining: 2.26s
# 156:	total: 8.07s	remaining: 2.21s
# 157:	total: 8.12s	remaining: 2.16s
# 158:	total: 8.18s	remaining: 2.11s
# 159:	total: 8.22s	remaining: 2.06s
# 160:	total: 8.3s	remaining: 2.01s
# 161:	total: 8.37s	remaining: 1.96s
# 162:	total: 8.42s	remaining: 1.91s
# 163:	total: 8.47s	remaining: 1.86s
# 164:	total: 8.53s	remaining: 1.81s
# 165:	total: 8.59s	remaining: 1.76s
# 166:	total: 8.66s	remaining: 1.71s
# 167:	total: 8.74s	remaining: 1.67s
# 168:	total: 8.83s	remaining: 1.62s
# 169:	total: 8.9s	remaining: 1.57s
# 170:	total: 8.97s	remaining: 1.52s
# 171:	total: 9.03s	remaining: 1.47s
# 172:	total: 9.08s	remaining: 1.42s
# 173:	total: 9.14s	remaining: 1.37s
# 174:	total: 9.22s	remaining: 1.32s
# 175:	total: 9.28s	remaining: 1.26s
# 176:	total: 9.35s	remaining: 1.21s
# 177:	total: 9.42s	remaining: 1.16s
# 178:	total: 9.47s	remaining: 1.11s
# 179:	total: 9.52s	remaining: 1.06s
# 180:	total: 9.57s	remaining: 1s
# 181:	total: 9.62s	remaining: 952ms
# 182:	total: 9.67s	remaining: 899ms
# 183:	total: 9.72s	remaining: 846ms
# 184:	total: 9.78s	remaining: 793ms
# 185:	total: 9.82s	remaining: 740ms
# 186:	total: 9.88s	remaining: 687ms
# 187:	total: 9.93s	remaining: 634ms
# 188:	total: 9.98s	remaining: 581ms
# 189:	total: 10s	remaining: 529ms
# 190:	total: 10.1s	remaining: 476ms
# 191:	total: 10.1s	remaining: 423ms
# 192:	total: 10.2s	remaining: 370ms
# 193:	total: 10.3s	remaining: 317ms
# 194:	total: 10.3s	remaining: 264ms
# 195:	total: 10.4s	remaining: 211ms
# 196:	total: 10.4s	remaining: 158ms
# 197:	total: 10.5s	remaining: 106ms
# 198:	total: 10.5s	remaining: 52.7ms
# 199:	total: 10.5s	remaining: 0us

# %%
print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))
# Out:
# XG-CV: 0.25966781672358985
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# RF-CV: 0.33097968739725225

# %%
x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print("{},{}".format(x_train.shape, x_test.shape))
# Out:
# (307511, 4),(48744, 4)

# %%
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
test['TARGET'] = logistic_regression.predict_proba(x_test)[:,1]

# %%
test[['SK_ID_CURR', 'TARGET']].to_csv('first_submission.csv', index=False, float_format='%.8f')
